# %% [markdown]
# ### Simple copy

# %%
import os
import random
import shutil

def copy_random_images(source_folder, destination_folder, num_images):
    if not os.path.exists(source_folder):
        print(f"Source folder '{source_folder}' does not exist.")
        return
        
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    image_files = [file for file in os.listdir(source_folder) if file.endswith(('.png'))]

    if len(image_files) < num_images:
        print(f"There are only {len(image_files)} images in the source folder. Cannot copy {num_images} images.")
        return

    selected_images = random.sample(image_files, num_images)

    for image in selected_images:
        source_path = os.path.join(source_folder, image)
        destination_path = os.path.join(destination_folder, image)
        shutil.copyfile(source_path, destination_path)
        print(f"Image '{image}' copied to '{destination_folder}'")

source_folder = 'good'
destination_folder = 'train'
num_images_to_copy = 550

copy_random_images(source_folder, destination_folder, num_images_to_copy)
# Out:
# Image 'Sample 754.png' copied to 'train'
# Image 'Sample 792.png' copied to 'train'
# Image 'Sample 381.png' copied to 'train'
# Image 'Sample 769.png' copied to 'train'
# Image 'Sample 727.png' copied to 'train'
# Image 'Sample 406.png' copied to 'train'
# Image 'Sample 831.png' copied to 'train'
# Image 'Sample 414.png' copied to 'train'
# Image 'Sample 564.png' copied to 'train'
# Image 'Sample 971.png' copied to 'train'
# Image 'Sample 842.png' copied to 'train'
# Image 'Sample 205.png' copied to 'train'
# Image 'Sample 215.png' copied to 'train'
# Image 'Sample 565.png' copied to 'train'
# Image 'Sample 342.png' copied to 'train'
# Image 'Sample 882.png' copied to 'train'
# Image 'Sample 835.png' copied to 'train'
# Image 'Sample 268.png' copied to 'train'
# Image 'Sample 943.png' copied to 'train'
# Image 'Sample 499.png' copied to 'train'
# Image 'Sample 102.png' copied to 'train'
# Image 'Sample 538.png' copied to 'train'
# Image 'Sample 478.png' copied to 'train'
# Image 'Sample 497.png' copied to 'train'
# Image 'Sample 967.png' copied to 'train'
# Image 'Sample 981.png' copied to 'train'
# Image 'Sample 885.png' copied to 'train'
# Image 'Sample 582.png' copied to 'train'
# Image 'Sample 737.png' copied to 'train'
# Image 'Sample 143.png' copied to 'train'
# Image 'Sample 130.png' copied to 'train'
# Image 'Sample 924.png' copied to 'train'
# Image 'Sample 906.png' copied to 'train'
# Image 'Sample 980.png' copied to 'train'
# Image 'Sample 148.png' copied to 'train'
# Image 'Sample 984.png' copied to 'train'
# Image 'Sample 151.png' copied to 'train'
# Image 'Sample 217.png' copied to 'train'
# Image 'Sample 645.png' copied to 'train'
# Image 'Sample 927.png' copied to 'train'
# Image 'Sample 805.png' copied to 'train'
# Image 'Sample 374.png' copied to 'train'
# Image 'Sample 77.png' copied to 'train'
# Image 'Sample 599.png' copied to 'train'
# Image 'Sample 635.png' copied to 'train'
# Image 'Sample 15.png' copied to 'train'
# Image 'Sample 498.png' copied to 'train'
# Image 'Sample 460.png' copied to 'train'
# Image 'Sample 990.png' copied to 'train'
# Image 'Sample 788.png' copied to 'train'
# Image 'Sample 471.png' copied to 'train'
# Image 'Sample 532.png' copied to 'train'
# Image 'Sample 89.png' copied to 'train'
# Image 'Sample 955.png' copied to 'train'
# Image 'Sample 361.png' copied to 'train'
# Image 'Sample 180.png' copied to 'train'
# Image 'Sample 158.png' copied to 'train'
# Image 'Sample 187.png' copied to 'train'
# Image 'Sample 80.png' copied to 'train'
# Image 'Sample 936.png' copied to 'train'
# Image 'Sample 527.png' copied to 'train'
# Image 'Sample 473.png' copied to 'train'
# Image 'Sample 751.png' copied to 'train'
# Image 'Sample 567.png' copied to 'train'
# Image 'Sample 815.png' copied to 'train'
# Image 'Sample 422.png' copied to 'train'
# Image 'Sample 178.png' copied to 'train'
# Image 'Sample 717.png' copied to 'train'
# Image 'Sample 166.png' copied to 'train'
# Image 'Sample 375.png' copied to 'train'
# Image 'Sample 449.png' copied to 'train'
# Image 'Sample 27.png' copied to 'train'
# Image 'Sample 957.png' copied to 'train'
# Image 'Sample 706.png' copied to 'train'
# Image 'Sample 719.png' copied to 'train'
# Image 'Sample 191.png' copied to 'train'
# Image 'Sample 10.png' copied to 'train'
# Image 'Sample 691.png' copied to 'train'
# Image 'Sample 108.png' copied to 'train'
# Image 'Sample 452.png' copied to 'train'
# Image 'Sample 14.png' copied to 'train'
# Image 'Sample 186.png' copied to 'train'
# Image 'Sample 224.png' copied to 'train'
# Image 'Sample 221.png' copied to 'train'
# Image 'Sample 570.png' copied to 'train'
# Image 'Sample 298.png' copied to 'train'
# Image 'Sample 881.png' copied to 'train'
# Image 'Sample 293.png' copied to 'train'
# Image 'Sample 920.png' copied to 'train'
# Image 'Sample 172.png' copied to 'train'
# Image 'Sample 325.png' copied to 'train'
# Image 'Sample 245.png' copied to 'train'
# Image 'Sample 24.png' copied to 'train'
# Image 'Sample 679.png' copied to 'train'
# Image 'Sample 784.png' copied to 'train'
# Image 'Sample 448.png' copied to 'train'
# Image 'Sample 959.png' copied to 'train'
# Image 'Sample 515.png' copied to 'train'
# Image 'Sample 741.png' copied to 'train'
# Image 'Sample 140.png' copied to 'train'
# Image 'Sample 306.png' copied to 'train'
# Image 'Sample 827.png' copied to 'train'
# Image 'Sample 833.png' copied to 'train'
# Image 'Sample 336.png' copied to 'train'
# Image 'Sample 973.png' copied to 'train'
# Image 'Sample 787.png' copied to 'train'
# Image 'Sample 641.png' copied to 'train'
# Image 'Sample 288.png' copied to 'train'
# Image 'Sample 85.png' copied to 'train'
# Image 'Sample 665.png' copied to 'train'
# Image 'Sample 235.png' copied to 'train'
# Image 'Sample 212.png' copied to 'train'
# Image 'Sample 195.png' copied to 'train'
# Image 'Sample 82.png' copied to 'train'
# Image 'Sample 710.png' copied to 'train'
# Image 'Sample 654.png' copied to 'train'
# Image 'Sample 786.png' copied to 'train'
# Image 'Sample 688.png' copied to 'train'
# Image 'Sample 888.png' copied to 'train'
# Image 'Sample 712.png' copied to 'train'
# Image 'Sample 225.png' copied to 'train'
# Image 'Sample 162.png' copied to 'train'
# Image 'Sample 458.png' copied to 'train'
# Image 'Sample 653.png' copied to 'train'
# Image 'Sample 514.png' copied to 'train'
# Image 'Sample 818.png' copied to 'train'
# Image 'Sample 697.png' copied to 'train'
# Image 'Sample 153.png' copied to 'train'
# Image 'Sample 569.png' copied to 'train'
# Image 'Sample 118.png' copied to 'train'
# Image 'Sample 902.png' copied to 'train'
# Image 'Sample 272.png' copied to 'train'
# Image 'Sample 708.png' copied to 'train'
# Image 'Sample 301.png' copied to 'train'
# Image 'Sample 28.png' copied to 'train'
# Image 'Sample 486.png' copied to 'train'
# Image 'Sample 817.png' copied to 'train'
# Image 'Sample 316.png' copied to 'train'
# Image 'Sample 425.png' copied to 'train'
# Image 'Sample 255.png' copied to 'train'
# Image 'Sample 761.png' copied to 'train'
# Image 'Sample 941.png' copied to 'train'
# Image 'Sample 365.png' copied to 'train'
# Image 'Sample 385.png' copied to 'train'
# Image 'Sample 330.png' copied to 'train'
# Image 'Sample 622.png' copied to 'train'
# Image 'Sample 355.png' copied to 'train'
# Image 'Sample 282.png' copied to 'train'
# Image 'Sample 624.png' copied to 'train'
# Image 'Sample 953.png' copied to 'train'
# Image 'Sample 951.png' copied to 'train'
# Image 'Sample 179.png' copied to 'train'
# Image 'Sample 344.png' copied to 'train'
# Image 'Sample 241.png' copied to 'train'
# Image 'Sample 687.png' copied to 'train'
# Image 'Sample 199.png' copied to 'train'
# Image 'Sample 747.png' copied to 'train'
# Image 'Sample 341.png' copied to 'train'
# Image 'Sample 168.png' copied to 'train'
# Image 'Sample 259.png' copied to 'train'
# Image 'Sample 535.png' copied to 'train'
# Image 'Sample 600.png' copied to 'train'
# Image 'Sample 490.png' copied to 'train'
# Image 'Sample 695.png' copied to 'train'
# Image 'Sample 922.png' copied to 'train'
# Image 'Sample 281.png' copied to 'train'
# Image 'Sample 614.png' copied to 'train'
# Image 'Sample 750.png' copied to 'train'
# Image 'Sample 2.png' copied to 'train'
# Image 'Sample 443.png' copied to 'train'
# Image 'Sample 720.png' copied to 'train'
# Image 'Sample 808.png' copied to 'train'
# Image 'Sample 456.png' copied to 'train'
# Image 'Sample 682.png' copied to 'train'
# Image 'Sample 119.png' copied to 'train'
# Image 'Sample 350.png' copied to 'train'
# Image 'Sample 593.png' copied to 'train'
# Image 'Sample 536.png' copied to 'train'
# Image 'Sample 929.png' copied to 'train'
# Image 'Sample 855.png' copied to 'train'
# Image 'Sample 629.png' copied to 'train'
# Image 'Sample 714.png' copied to 'train'
# Image 'Sample 233.png' copied to 'train'
# Image 'Sample 738.png' copied to 'train'
# Image 'Sample 488.png' copied to 'train'
# Image 'Sample 327.png' copied to 'train'
# Image 'Sample 16.png' copied to 'train'
# Image 'Sample 313.png' copied to 'train'
# Image 'Sample 668.png' copied to 'train'
# Image 'Sample 43.png' copied to 'train'
# Image 'Sample 946.png' copied to 'train'
# Image 'Sample 286.png' copied to 'train'
# Image 'Sample 699.png' copied to 'train'
# Image 'Sample 844.png' copied to 'train'
# Image 'Sample 157.png' copied to 'train'
# Image 'Sample 262.png' copied to 'train'
# Image 'Sample 94.png' copied to 'train'
# Image 'Sample 676.png' copied to 'train'
# Image 'Sample 474.png' copied to 'train'
# Image 'Sample 828.png' copied to 'train'
# Image 'Sample 487.png' copied to 'train'
# Image 'Sample 776.png' copied to 'train'
# Image 'Sample 475.png' copied to 'train'
# Image 'Sample 294.png' copied to 'train'
# Image 'Sample 496.png' copied to 'train'
# Image 'Sample 777.png' copied to 'train'
# Image 'Sample 429.png' copied to 'train'
# Image 'Sample 304.png' copied to 'train'
# Image 'Sample 870.png' copied to 'train'
# Image 'Sample 18.png' copied to 'train'
# Image 'Sample 315.png' copied to 'train'
# Image 'Sample 114.png' copied to 'train'
# Image 'Sample 142.png' copied to 'train'
# Image 'Sample 619.png' copied to 'train'
# Image 'Sample 998.png' copied to 'train'
# Image 'Sample 427.png' copied to 'train'
# Image 'Sample 975.png' copied to 'train'
# Image 'Sample 502.png' copied to 'train'
# Image 'Sample 93.png' copied to 'train'
# Image 'Sample 522.png' copied to 'train'
# Image 'Sample 208.png' copied to 'train'
# Image 'Sample 623.png' copied to 'train'
# Image 'Sample 135.png' copied to 'train'
# Image 'Sample 489.png' copied to 'train'
# Image 'Sample 328.png' copied to 'train'
# Image 'Sample 348.png' copied to 'train'
# Image 'Sample 812.png' copied to 'train'
# Image 'Sample 329.png' copied to 'train'
# Image 'Sample 890.png' copied to 'train'
# Image 'Sample 62.png' copied to 'train'
# Image 'Sample 59.png' copied to 'train'
# Image 'Sample 53.png' copied to 'train'
# Image 'Sample 65.png' copied to 'train'
# Image 'Sample 335.png' copied to 'train'
# Image 'Sample 150.png' copied to 'train'
# Image 'Sample 988.png' copied to 'train'
# Image 'Sample 945.png' copied to 'train'
# Image 'Sample 156.png' copied to 'train'
# Image 'Sample 809.png' copied to 'train'
# Image 'Sample 905.png' copied to 'train'
# Image 'Sample 334.png' copied to 'train'
# Image 'Sample 562.png' copied to 'train'
# Image 'Sample 779.png' copied to 'train'
# Image 'Sample 189.png' copied to 'train'
# Image 'Sample 960.png' copied to 'train'
# Image 'Sample 252.png' copied to 'train'
# Image 'Sample 167.png' copied to 'train'
# Image 'Sample 782.png' copied to 'train'
# Image 'Sample 637.png' copied to 'train'
# Image 'Sample 628.png' copied to 'train'
# Image 'Sample 558.png' copied to 'train'
# Image 'Sample 716.png' copied to 'train'
# Image 'Sample 109.png' copied to 'train'
# Image 'Sample 31.png' copied to 'train'
# Image 'Sample 126.png' copied to 'train'
# Image 'Sample 263.png' copied to 'train'
# Image 'Sample 773.png' copied to 'train'
# Image 'Sample 541.png' copied to 'train'
# Image 'Sample 932.png' copied to 'train'
# Image 'Sample 236.png' copied to 'train'
# Image 'Sample 165.png' copied to 'train'
# Image 'Sample 807.png' copied to 'train'
# Image 'Sample 663.png' copied to 'train'
# Image 'Sample 402.png' copied to 'train'
# Image 'Sample 11.png' copied to 'train'
# Image 'Sample 493.png' copied to 'train'
# Image 'Sample 742.png' copied to 'train'
# Image 'Sample 698.png' copied to 'train'
# Image 'Sample 939.png' copied to 'train'
# Image 'Sample 265.png' copied to 'train'
# Image 'Sample 308.png' copied to 'train'
# Image 'Sample 607.png' copied to 'train'
# Image 'Sample 321.png' copied to 'train'
# Image 'Sample 192.png' copied to 'train'
# Image 'Sample 675.png' copied to 'train'
# Image 'Sample 947.png' copied to 'train'
# Image 'Sample 584.png' copied to 'train'
# Image 'Sample 399.png' copied to 'train'
# Image 'Sample 97.png' copied to 'train'
# Image 'Sample 78.png' copied to 'train'
# Image 'Sample 606.png' copied to 'train'
# Image 'Sample 871.png' copied to 'train'
# Image 'Sample 948.png' copied to 'train'
# Image 'Sample 407.png' copied to 'train'
# Image 'Sample 958.png' copied to 'train'
# Image 'Sample 774.png' copied to 'train'
# Image 'Sample 363.png' copied to 'train'
# Image 'Sample 930.png' copied to 'train'
# Image 'Sample 444.png' copied to 'train'
# Image 'Sample 279.png' copied to 'train'
# Image 'Sample 390.png' copied to 'train'
# Image 'Sample 349.png' copied to 'train'
# Image 'Sample 347.png' copied to 'train'
# Image 'Sample 70.png' copied to 'train'
# Image 'Sample 450.png' copied to 'train'
# Image 'Sample 380.png' copied to 'train'
# Image 'Sample 547.png' copied to 'train'
# Image 'Sample 554.png' copied to 'train'
# Image 'Sample 413.png' copied to 'train'
# Image 'Sample 615.png' copied to 'train'
# Image 'Sample 416.png' copied to 'train'
# Image 'Sample 372.png' copied to 'train'
# Image 'Sample 875.png' copied to 'train'
# Image 'Sample 314.png' copied to 'train'
# Image 'Sample 591.png' copied to 'train'
# Image 'Sample 271.png' copied to 'train'
# Image 'Sample 768.png' copied to 'train'
# Image 'Sample 850.png' copied to 'train'
# Image 'Sample 666.png' copied to 'train'
# Image 'Sample 368.png' copied to 'train'
# Image 'Sample 849.png' copied to 'train'
# Image 'Sample 6.png' copied to 'train'
# Image 'Sample 783.png' copied to 'train'
# Image 'Sample 543.png' copied to 'train'
# Image 'Sample 144.png' copied to 'train'
# Image 'Sample 983.png' copied to 'train'
# Image 'Sample 229.png' copied to 'train'
# Image 'Sample 104.png' copied to 'train'
# Image 'Sample 529.png' copied to 'train'
# Image 'Sample 463.png' copied to 'train'
# Image 'Sample 234.png' copied to 'train'
# Image 'Sample 638.png' copied to 'train'
# Image 'Sample 21.png' copied to 'train'
# Image 'Sample 824.png' copied to 'train'
# Image 'Sample 597.png' copied to 'train'
# Image 'Sample 821.png' copied to 'train'
# Image 'Sample 417.png' copied to 'train'
# Image 'Sample 228.png' copied to 'train'
# Image 'Sample 573.png' copied to 'train'
# Image 'Sample 851.png' copied to 'train'
# Image 'Sample 963.png' copied to 'train'
# Image 'Sample 500.png' copied to 'train'
# Image 'Sample 685.png' copied to 'train'
# Image 'Sample 590.png' copied to 'train'
# Image 'Sample 366.png' copied to 'train'
# Image 'Sample 48.png' copied to 'train'
# Image 'Sample 477.png' copied to 'train'
# Image 'Sample 397.png' copied to 'train'
# Image 'Sample 523.png' copied to 'train'
# Image 'Sample 359.png' copied to 'train'
# Image 'Sample 242.png' copied to 'train'
# Image 'Sample 163.png' copied to 'train'
# Image 'Sample 655.png' copied to 'train'
# Image 'Sample 17.png' copied to 'train'
# Image 'Sample 954.png' copied to 'train'
# Image 'Sample 324.png' copied to 'train'
# Image 'Sample 116.png' copied to 'train'
# Image 'Sample 121.png' copied to 'train'
# Image 'Sample 52.png' copied to 'train'
# Image 'Sample 485.png' copied to 'train'
# Image 'Sample 609.png' copied to 'train'
# Image 'Sample 690.png' copied to 'train'
# Image 'Sample 412.png' copied to 'train'
# Image 'Sample 393.png' copied to 'train'
# Image 'Sample 802.png' copied to 'train'
# Image 'Sample 760.png' copied to 'train'
# Image 'Sample 45.png' copied to 'train'
# Image 'Sample 966.png' copied to 'train'
# Image 'Sample 853.png' copied to 'train'
# Image 'Sample 772.png' copied to 'train'
# Image 'Sample 804.png' copied to 'train'
# Image 'Sample 670.png' copied to 'train'
# Image 'Sample 650.png' copied to 'train'
# Image 'Sample 35.png' copied to 'train'
# Image 'Sample 730.png' copied to 'train'
# Image 'Sample 103.png' copied to 'train'
# Image 'Sample 494.png' copied to 'train'
# Image 'Sample 159.png' copied to 'train'
# Image 'Sample 371.png' copied to 'train'
# Image 'Sample 794.png' copied to 'train'
# Image 'Sample 264.png' copied to 'train'
# Image 'Sample 183.png' copied to 'train'
# Image 'Sample 247.png' copied to 'train'
# Image 'Sample 950.png' copied to 'train'
# Image 'Sample 66.png' copied to 'train'
# Image 'Sample 146.png' copied to 'train'
# Image 'Sample 367.png' copied to 'train'
# Image 'Sample 300.png' copied to 'train'
# Image 'Sample 433.png' copied to 'train'
# Image 'Sample 874.png' copied to 'train'
# Image 'Sample 200.png' copied to 'train'
# Image 'Sample 571.png' copied to 'train'
# Image 'Sample 539.png' copied to 'train'
# Image 'Sample 918.png' copied to 'train'
# Image 'Sample 519.png' copied to 'train'
# Image 'Sample 193.png' copied to 'train'
# Image 'Sample 847.png' copied to 'train'
# Image 'Sample 454.png' copied to 'train'
# Image 'Sample 377.png' copied to 'train'
# Image 'Sample 778.png' copied to 'train'
# Image 'Sample 986.png' copied to 'train'
# Image 'Sample 860.png' copied to 'train'
# Image 'Sample 479.png' copied to 'train'
# Image 'Sample 854.png' copied to 'train'
# Image 'Sample 834.png' copied to 'train'
# Image 'Sample 254.png' copied to 'train'
# Image 'Sample 681.png' copied to 'train'
# Image 'Sample 246.png' copied to 'train'
# Image 'Sample 231.png' copied to 'train'
# Image 'Sample 451.png' copied to 'train'
# Image 'Sample 938.png' copied to 'train'
# Image 'Sample 636.png' copied to 'train'
# Image 'Sample 74.png' copied to 'train'
# Image 'Sample 323.png' copied to 'train'
# Image 'Sample 914.png' copied to 'train'
# Image 'Sample 19.png' copied to 'train'
# Image 'Sample 611.png' copied to 'train'
# Image 'Sample 220.png' copied to 'train'
# Image 'Sample 859.png' copied to 'train'
# Image 'Sample 789.png' copied to 'train'
# Image 'Sample 796.png' copied to 'train'
# Image 'Sample 661.png' copied to 'train'
# Image 'Sample 839.png' copied to 'train'
# Image 'Sample 437.png' copied to 'train'
# Image 'Sample 72.png' copied to 'train'
# Image 'Sample 557.png' copied to 'train'
# Image 'Sample 511.png' copied to 'train'
# Image 'Sample 352.png' copied to 'train'
# Image 'Sample 627.png' copied to 'train'
# Image 'Sample 596.png' copied to 'train'
# Image 'Sample 75.png' copied to 'train'
# Image 'Sample 689.png' copied to 'train'
# Image 'Sample 170.png' copied to 'train'
# Image 'Sample 56.png' copied to 'train'
# Image 'Sample 128.png' copied to 'train'
# Image 'Sample 762.png' copied to 'train'
# Image 'Sample 428.png' copied to 'train'
# Image 'Sample 129.png' copied to 'train'
# Image 'Sample 232.png' copied to 'train'
# Image 'Sample 911.png' copied to 'train'
# Image 'Sample 612.png' copied to 'train'
# Image 'Sample 659.png' copied to 'train'
# Image 'Sample 132.png' copied to 'train'
# Image 'Sample 311.png' copied to 'train'
# Image 'Sample 883.png' copied to 'train'
# Image 'Sample 530.png' copied to 'train'
# Image 'Sample 813.png' copied to 'train'
# Image 'Sample 702.png' copied to 'train'
# Image 'Sample 583.png' copied to 'train'
# Image 'Sample 36.png' copied to 'train'
# Image 'Sample 357.png' copied to 'train'
# Image 'Sample 226.png' copied to 'train'
# Image 'Sample 552.png' copied to 'train'
# Image 'Sample 733.png' copied to 'train'
# Image 'Sample 46.png' copied to 'train'
# Image 'Sample 721.png' copied to 'train'
# Image 'Sample 968.png' copied to 'train'
# Image 'Sample 459.png' copied to 'train'
# Image 'Sample 23.png' copied to 'train'
# Image 'Sample 136.png' copied to 'train'
# Image 'Sample 1.png' copied to 'train'
# Image 'Sample 87.png' copied to 'train'
# Image 'Sample 713.png' copied to 'train'
# Image 'Sample 127.png' copied to 'train'
# Image 'Sample 198.png' copied to 'train'
# Image 'Sample 800.png' copied to 'train'
# Image 'Sample 426.png' copied to 'train'
# Image 'Sample 248.png' copied to 'train'
# Image 'Sample 7.png' copied to 'train'
# Image 'Sample 409.png' copied to 'train'
# Image 'Sample 765.png' copied to 'train'
# Image 'Sample 602.png' copied to 'train'
# Image 'Sample 775.png' copied to 'train'
# Image 'Sample 846.png' copied to 'train'
# Image 'Sample 266.png' copied to 'train'
# Image 'Sample 373.png' copied to 'train'
# Image 'Sample 972.png' copied to 'train'
# Image 'Sample 182.png' copied to 'train'
# Image 'Sample 47.png' copied to 'train'
# Image 'Sample 273.png' copied to 'train'
# Image 'Sample 112.png' copied to 'train'
# Image 'Sample 61.png' copied to 'train'
# Image 'Sample 472.png' copied to 'train'
# Image 'Sample 718.png' copied to 'train'
# Image 'Sample 423.png' copied to 'train'
# Image 'Sample 746.png' copied to 'train'
# Image 'Sample 317.png' copied to 'train'
# Image 'Sample 184.png' copied to 'train'
# Image 'Sample 310.png' copied to 'train'
# Image 'Sample 933.png' copied to 'train'
# Image 'Sample 81.png' copied to 'train'
# Image 'Sample 516.png' copied to 'train'
# Image 'Sample 711.png' copied to 'train'
# Image 'Sample 44.png' copied to 'train'
# Image 'Sample 491.png' copied to 'train'
# Image 'Sample 517.png' copied to 'train'
# Image 'Sample 574.png' copied to 'train'
# Image 'Sample 684.png' copied to 'train'
# Image 'Sample 391.png' copied to 'train'
# Image 'Sample 790.png' copied to 'train'
# Image 'Sample 785.png' copied to 'train'
# Image 'Sample 26.png' copied to 'train'
# Image 'Sample 434.png' copied to 'train'
# Image 'Sample 664.png' copied to 'train'
# Image 'Sample 90.png' copied to 'train'
# Image 'Sample 568.png' copied to 'train'
# Image 'Sample 862.png' copied to 'train'
# Image 'Sample 526.png' copied to 'train'
# Image 'Sample 283.png' copied to 'train'
# Image 'Sample 295.png' copied to 'train'
# Image 'Sample 194.png' copied to 'train'
# Image 'Sample 820.png' copied to 'train'
# Image 'Sample 531.png' copied to 'train'
# Image 'Sample 759.png' copied to 'train'
# Image 'Sample 396.png' copied to 'train'
# Image 'Sample 880.png' copied to 'train'
# Image 'Sample 755.png' copied to 'train'
# Image 'Sample 964.png' copied to 'train'
# Image 'Sample 749.png' copied to 'train'
# Image 'Sample 997.png' copied to 'train'
# Image 'Sample 555.png' copied to 'train'
# Image 'Sample 589.png' copied to 'train'
# Image 'Sample 553.png' copied to 'train'
# Image 'Sample 693.png' copied to 'train'
# Image 'Sample 703.png' copied to 'train'
# Image 'Sample 276.png' copied to 'train'
# Image 'Sample 424.png' copied to 'train'
# Image 'Sample 652.png' copied to 'train'
# Image 'Sample 649.png' copied to 'train'
# Image 'Sample 550.png' copied to 'train'
# Image 'Sample 942.png' copied to 'train'
# Image 'Sample 38.png' copied to 'train'
# Image 'Sample 421.png' copied to 'train'
# Image 'Sample 9.png' copied to 'train'
# Image 'Sample 877.png' copied to 'train'
# Image 'Sample 309.png' copied to 'train'
# Image 'Sample 724.png' copied to 'train'
# Image 'Sample 680.png' copied to 'train'
# Image 'Sample 658.png' copied to 'train'
# Image 'Sample 123.png' copied to 'train'
# Image 'Sample 197.png' copied to 'train'
# Image 'Sample 190.png' copied to 'train'
# Image 'Sample 506.png' copied to 'train'
# Image 'Sample 84.png' copied to 'train'
# Image 'Sample 907.png' copied to 'train'
# Image 'Sample 256.png' copied to 'train'
# Image 'Sample 921.png' copied to 'train'
# Image 'Sample 919.png' copied to 'train'
# Image 'Sample 139.png' copied to 'train'
# Image 'Sample 598.png' copied to 'train'
# Image 'Sample 176.png' copied to 'train'
# Image 'Sample 370.png' copied to 'train'
# Image 'Sample 492.png' copied to 'train'
# Image 'Sample 13.png' copied to 'train'
# Image 'Sample 743.png' copied to 'train'
# Image 'Sample 164.png' copied to 'train'
# Image 'Sample 439.png' copied to 'train'
# Image 'Sample 403.png' copied to 'train'
# Image 'Sample 791.png' copied to 'train'
# Image 'Sample 923.png' copied to 'train'

# %% [markdown]
# ## Dataset split - 4 class

# %%
import os
import shutil
import random

# Define directories
data_directory = './Categorical Data'  # Directory containing class directories
train_directory = './Categorical Data/train'  # Directory to store train data
test_directory = './Categorical Data/test'  # Directory to store test data

# Create train and test directories if they don't exist
os.makedirs(train_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

# Define the percentage of data to allocate for testing (e.g., 20%)
test_split = 0.3

# Iterate through each class directory
for class_label in ['good', 'resonator', 'centermass', 'diaphragm']:
    class_directory = os.path.join(data_directory, class_label)
    
    # Create train and test directories for the current class
    train_class_directory = os.path.join(train_directory, class_label)
    test_class_directory = os.path.join(test_directory, class_label)
    os.makedirs(train_class_directory, exist_ok=True)
    os.makedirs(test_class_directory, exist_ok=True)
    
    # Get list of image files in the class directory
    image_files = os.listdir(class_directory)
    
    # Shuffle the image files randomly
    random.shuffle(image_files)
    
    # Split the data into train and test sets
    num_test_samples = int(len(image_files) * test_split)
    test_samples = image_files[:num_test_samples]
    train_samples = image_files[num_test_samples:]
    
    # Move train images to the train directory
    for train_image in train_samples:
        src_train = os.path.join(class_directory, train_image)
        dst_train = os.path.join(train_class_directory, train_image)
        shutil.copy(src_train, dst_train)
    
    # Move test images to the test directory
    for test_image in test_samples:
        src_test = os.path.join(class_directory, test_image)
        dst_test = os.path.join(test_class_directory, test_image)
        shutil.copy(src_test, dst_test)

print("Data split completed successfully.")
# Out:
# Data split completed successfully.

# %% [markdown]
# ## Dataset split - 2 class

# %%
import os
import shutil
import random

# Define directories
data_directory = './'  # Directory containing class directories
train_directory = './train'  # Directory to store train data
test_directory = './test'  # Directory to store test data

# Create train and test directories if they don't exist
os.makedirs(train_directory, exist_ok=True)
os.makedirs(test_directory, exist_ok=True)

# Define the number of samples for each class
num_good_samples_train = 550
num_bad_samples_train = 150

# Define the percentage of data to allocate for testing (e.g., 20%)
test_split_ratio = 0.2

# Define the 'bad' classes
bad_classes = ['resonator', 'centermass', 'diaphragm']

# Iterate through each class directory
for class_label in ['good'] + bad_classes:
    class_directory = os.path.join(data_directory, class_label)

    # Create train and test directories for the current class
    train_class_directory = os.path.join(train_directory, class_label)
    test_class_directory = os.path.join(test_directory, class_label)
    os.makedirs(train_class_directory, exist_ok=True)
    os.makedirs(test_class_directory, exist_ok=True)

    # Get list of image files in the class directory
    image_files = os.listdir(class_directory)

    # Shuffle the image files randomly
    random.shuffle(image_files)

    # Determine the number of samples for train and test sets
    if class_label == 'good':
        num_train_samples = min(num_good_samples_train, len(image_files))
        num_test_samples = int(num_train_samples * test_split_ratio)
    else:
        num_train_samples = num_bad_samples_train
        num_test_samples = int(num_train_samples * test_split_ratio)

    # Split the data into train and test sets
    train_samples = image_files[:num_train_samples]
    test_samples = image_files[num_train_samples:num_train_samples + num_test_samples]

    # Copy train images to the train directory
    for train_image in train_samples:
        src_train = os.path.join(class_directory, train_image)
        dst_train = os.path.join(train_class_directory, train_image)
        shutil.copy(src_train, dst_train)

    # Copy test images to the test directory
    for test_image in test_samples:
        src_test = os.path.join(class_directory, test_image)
        dst_test = os.path.join(test_class_directory, test_image)
        shutil.copy(src_test, dst_test)

print("Data split completed successfully.")
# Out:
# Data split completed successfully.

# %% [markdown]
# #### Train

# %%
import os
import shutil

def copy_and_rename_images(source_folders, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Initialize a counter for renaming
    counter = 1

    # Loop through each source folder
    for folder in source_folders:
        # Check if the source folder exists
        if not os.path.exists(folder):
            print(f"Source folder '{folder}' does not exist.")
            continue

        # Get list of image files in the source folder
        image_files = [file for file in os.listdir(folder) if file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]

        # Copy and rename each image
        for image in image_files:
            source_path = os.path.join(folder, image)
            destination_path = os.path.join(destination_folder, f"Sample {counter}.png")  # Renaming as Sample{counter}.jpg
            shutil.copyfile(source_path, destination_path)
            print(f"Image '{image}' copied and renamed to 'Sample {counter}.png'")
            counter += 1

# Source folders
source_folders = ['./train/resonator', './train/centermass', './train/diaphragm']
destination_folder = './train/defected'

# Copy and rename images
copy_and_rename_images(source_folders, destination_folder)
# Out:
# Image 'Sample 10.png' copied and renamed to 'Sample 1.png'
# Image 'Sample 110.png' copied and renamed to 'Sample 2.png'
# Image 'Sample 119.png' copied and renamed to 'Sample 3.png'
# Image 'Sample 121.png' copied and renamed to 'Sample 4.png'
# Image 'Sample 127.png' copied and renamed to 'Sample 5.png'
# Image 'Sample 130.png' copied and renamed to 'Sample 6.png'
# Image 'Sample 133.png' copied and renamed to 'Sample 7.png'
# Image 'Sample 137.png' copied and renamed to 'Sample 8.png'
# Image 'Sample 140.png' copied and renamed to 'Sample 9.png'
# Image 'Sample 142.png' copied and renamed to 'Sample 10.png'
# Image 'Sample 143.png' copied and renamed to 'Sample 11.png'
# Image 'Sample 147.png' copied and renamed to 'Sample 12.png'
# Image 'Sample 157.png' copied and renamed to 'Sample 13.png'
# Image 'Sample 167.png' copied and renamed to 'Sample 14.png'
# Image 'Sample 168.png' copied and renamed to 'Sample 15.png'
# Image 'Sample 170.png' copied and renamed to 'Sample 16.png'
# Image 'Sample 172.png' copied and renamed to 'Sample 17.png'
# Image 'Sample 175.png' copied and renamed to 'Sample 18.png'
# Image 'Sample 185.png' copied and renamed to 'Sample 19.png'
# Image 'Sample 186.png' copied and renamed to 'Sample 20.png'
# Image 'Sample 187.png' copied and renamed to 'Sample 21.png'
# Image 'Sample 19.png' copied and renamed to 'Sample 22.png'
# Image 'Sample 208.png' copied and renamed to 'Sample 23.png'
# Image 'Sample 209.png' copied and renamed to 'Sample 24.png'
# Image 'Sample 21.png' copied and renamed to 'Sample 25.png'
# Image 'Sample 212.png' copied and renamed to 'Sample 26.png'
# Image 'Sample 213.png' copied and renamed to 'Sample 27.png'
# Image 'Sample 225.png' copied and renamed to 'Sample 28.png'
# Image 'Sample 244.png' copied and renamed to 'Sample 29.png'
# Image 'Sample 260.png' copied and renamed to 'Sample 30.png'
# Image 'Sample 263.png' copied and renamed to 'Sample 31.png'
# Image 'Sample 268.png' copied and renamed to 'Sample 32.png'
# Image 'Sample 274.png' copied and renamed to 'Sample 33.png'
# Image 'Sample 28.png' copied and renamed to 'Sample 34.png'
# Image 'Sample 280.png' copied and renamed to 'Sample 35.png'
# Image 'Sample 286.png' copied and renamed to 'Sample 36.png'
# Image 'Sample 295.png' copied and renamed to 'Sample 37.png'
# Image 'Sample 304.png' copied and renamed to 'Sample 38.png'
# Image 'Sample 313.png' copied and renamed to 'Sample 39.png'
# Image 'Sample 317.png' copied and renamed to 'Sample 40.png'
# Image 'Sample 32.png' copied and renamed to 'Sample 41.png'
# Image 'Sample 320.png' copied and renamed to 'Sample 42.png'
# Image 'Sample 331.png' copied and renamed to 'Sample 43.png'
# Image 'Sample 335.png' copied and renamed to 'Sample 44.png'
# Image 'Sample 366.png' copied and renamed to 'Sample 45.png'
# Image 'Sample 369.png' copied and renamed to 'Sample 46.png'
# Image 'Sample 375.png' copied and renamed to 'Sample 47.png'
# Image 'Sample 376.png' copied and renamed to 'Sample 48.png'
# Image 'Sample 382.png' copied and renamed to 'Sample 49.png'
# Image 'Sample 397.png' copied and renamed to 'Sample 50.png'
# Image 'Sample 398.png' copied and renamed to 'Sample 51.png'
# Image 'Sample 399.png' copied and renamed to 'Sample 52.png'
# Image 'Sample 40.png' copied and renamed to 'Sample 53.png'
# Image 'Sample 401.png' copied and renamed to 'Sample 54.png'
# Image 'Sample 427.png' copied and renamed to 'Sample 55.png'
# Image 'Sample 435.png' copied and renamed to 'Sample 56.png'
# Image 'Sample 437.png' copied and renamed to 'Sample 57.png'
# Image 'Sample 451.png' copied and renamed to 'Sample 58.png'
# Image 'Sample 457.png' copied and renamed to 'Sample 59.png'
# Image 'Sample 460.png' copied and renamed to 'Sample 60.png'
# Image 'Sample 466.png' copied and renamed to 'Sample 61.png'
# Image 'Sample 472.png' copied and renamed to 'Sample 62.png'
# Image 'Sample 482.png' copied and renamed to 'Sample 63.png'
# Image 'Sample 490.png' copied and renamed to 'Sample 64.png'
# Image 'Sample 495.png' copied and renamed to 'Sample 65.png'
# Image 'Sample 500.png' copied and renamed to 'Sample 66.png'
# Image 'Sample 506.png' copied and renamed to 'Sample 67.png'
# Image 'Sample 508.png' copied and renamed to 'Sample 68.png'
# Image 'Sample 514.png' copied and renamed to 'Sample 69.png'
# Image 'Sample 520.png' copied and renamed to 'Sample 70.png'
# Image 'Sample 525.png' copied and renamed to 'Sample 71.png'
# Image 'Sample 531.png' copied and renamed to 'Sample 72.png'
# Image 'Sample 535.png' copied and renamed to 'Sample 73.png'
# Image 'Sample 537.png' copied and renamed to 'Sample 74.png'
# Image 'Sample 547.png' copied and renamed to 'Sample 75.png'
# Image 'Sample 55.png' copied and renamed to 'Sample 76.png'
# Image 'Sample 550.png' copied and renamed to 'Sample 77.png'
# Image 'Sample 567.png' copied and renamed to 'Sample 78.png'
# Image 'Sample 569.png' copied and renamed to 'Sample 79.png'
# Image 'Sample 575.png' copied and renamed to 'Sample 80.png'
# Image 'Sample 577.png' copied and renamed to 'Sample 81.png'
# Image 'Sample 583.png' copied and renamed to 'Sample 82.png'
# Image 'Sample 587.png' copied and renamed to 'Sample 83.png'
# Image 'Sample 594.png' copied and renamed to 'Sample 84.png'
# Image 'Sample 596.png' copied and renamed to 'Sample 85.png'
# Image 'Sample 599.png' copied and renamed to 'Sample 86.png'
# Image 'Sample 608.png' copied and renamed to 'Sample 87.png'
# Image 'Sample 61.png' copied and renamed to 'Sample 88.png'
# Image 'Sample 62.png' copied and renamed to 'Sample 89.png'
# Image 'Sample 625.png' copied and renamed to 'Sample 90.png'
# Image 'Sample 63.png' copied and renamed to 'Sample 91.png'
# Image 'Sample 630.png' copied and renamed to 'Sample 92.png'
# Image 'Sample 631.png' copied and renamed to 'Sample 93.png'
# Image 'Sample 635.png' copied and renamed to 'Sample 94.png'
# Image 'Sample 643.png' copied and renamed to 'Sample 95.png'
# Image 'Sample 645.png' copied and renamed to 'Sample 96.png'
# Image 'Sample 652.png' copied and renamed to 'Sample 97.png'
# Image 'Sample 667.png' copied and renamed to 'Sample 98.png'
# Image 'Sample 668.png' copied and renamed to 'Sample 99.png'
# Image 'Sample 679.png' copied and renamed to 'Sample 100.png'
# Image 'Sample 685.png' copied and renamed to 'Sample 101.png'
# Image 'Sample 69.png' copied and renamed to 'Sample 102.png'
# Image 'Sample 696.png' copied and renamed to 'Sample 103.png'
# Image 'Sample 70.png' copied and renamed to 'Sample 104.png'
# Image 'Sample 705.png' copied and renamed to 'Sample 105.png'
# Image 'Sample 712.png' copied and renamed to 'Sample 106.png'
# Image 'Sample 716.png' copied and renamed to 'Sample 107.png'
# Image 'Sample 721.png' copied and renamed to 'Sample 108.png'
# Image 'Sample 726.png' copied and renamed to 'Sample 109.png'
# Image 'Sample 730.png' copied and renamed to 'Sample 110.png'
# Image 'Sample 732.png' copied and renamed to 'Sample 111.png'
# Image 'Sample 733.png' copied and renamed to 'Sample 112.png'
# Image 'Sample 745.png' copied and renamed to 'Sample 113.png'
# Image 'Sample 752.png' copied and renamed to 'Sample 114.png'
# Image 'Sample 755.png' copied and renamed to 'Sample 115.png'
# Image 'Sample 763.png' copied and renamed to 'Sample 116.png'
# Image 'Sample 764.png' copied and renamed to 'Sample 117.png'
# Image 'Sample 767.png' copied and renamed to 'Sample 118.png'
# Image 'Sample 77.png' copied and renamed to 'Sample 119.png'
# Image 'Sample 810.png' copied and renamed to 'Sample 120.png'
# Image 'Sample 815.png' copied and renamed to 'Sample 121.png'
# Image 'Sample 816.png' copied and renamed to 'Sample 122.png'
# Image 'Sample 82.png' copied and renamed to 'Sample 123.png'
# Image 'Sample 820.png' copied and renamed to 'Sample 124.png'
# Image 'Sample 829.png' copied and renamed to 'Sample 125.png'
# Image 'Sample 842.png' copied and renamed to 'Sample 126.png'
# Image 'Sample 843.png' copied and renamed to 'Sample 127.png'
# Image 'Sample 850.png' copied and renamed to 'Sample 128.png'
# Image 'Sample 854.png' copied and renamed to 'Sample 129.png'
# Image 'Sample 863.png' copied and renamed to 'Sample 130.png'
# Image 'Sample 869.png' copied and renamed to 'Sample 131.png'
# Image 'Sample 871.png' copied and renamed to 'Sample 132.png'
# Image 'Sample 88.png' copied and renamed to 'Sample 133.png'
# Image 'Sample 883.png' copied and renamed to 'Sample 134.png'
# Image 'Sample 90.png' copied and renamed to 'Sample 135.png'
# Image 'Sample 909.png' copied and renamed to 'Sample 136.png'
# Image 'Sample 919.png' copied and renamed to 'Sample 137.png'
# Image 'Sample 920.png' copied and renamed to 'Sample 138.png'
# Image 'Sample 921.png' copied and renamed to 'Sample 139.png'
# Image 'Sample 928.png' copied and renamed to 'Sample 140.png'
# Image 'Sample 929.png' copied and renamed to 'Sample 141.png'
# Image 'Sample 938.png' copied and renamed to 'Sample 142.png'
# Image 'Sample 939.png' copied and renamed to 'Sample 143.png'
# Image 'Sample 941.png' copied and renamed to 'Sample 144.png'
# Image 'Sample 948.png' copied and renamed to 'Sample 145.png'
# Image 'Sample 955.png' copied and renamed to 'Sample 146.png'
# Image 'Sample 980.png' copied and renamed to 'Sample 147.png'
# Image 'Sample 984.png' copied and renamed to 'Sample 148.png'
# Image 'Sample 996.png' copied and renamed to 'Sample 149.png'
# Image 'Sample 997.png' copied and renamed to 'Sample 150.png'
# Image 'Sample 106.png' copied and renamed to 'Sample 151.png'
# Image 'Sample 111.png' copied and renamed to 'Sample 152.png'
# Image 'Sample 114.png' copied and renamed to 'Sample 153.png'
# Image 'Sample 121.png' copied and renamed to 'Sample 154.png'
# Image 'Sample 13.png' copied and renamed to 'Sample 155.png'
# Image 'Sample 137.png' copied and renamed to 'Sample 156.png'
# Image 'Sample 138.png' copied and renamed to 'Sample 157.png'
# Image 'Sample 139.png' copied and renamed to 'Sample 158.png'
# Image 'Sample 148.png' copied and renamed to 'Sample 159.png'
# Image 'Sample 150.png' copied and renamed to 'Sample 160.png'
# Image 'Sample 151.png' copied and renamed to 'Sample 161.png'
# Image 'Sample 154.png' copied and renamed to 'Sample 162.png'
# Image 'Sample 173.png' copied and renamed to 'Sample 163.png'
# Image 'Sample 194.png' copied and renamed to 'Sample 164.png'
# Image 'Sample 195.png' copied and renamed to 'Sample 165.png'
# Image 'Sample 199.png' copied and renamed to 'Sample 166.png'
# Image 'Sample 202.png' copied and renamed to 'Sample 167.png'
# Image 'Sample 209.png' copied and renamed to 'Sample 168.png'
# Image 'Sample 210.png' copied and renamed to 'Sample 169.png'
# Image 'Sample 219.png' copied and renamed to 'Sample 170.png'
# Image 'Sample 224.png' copied and renamed to 'Sample 171.png'
# Image 'Sample 236.png' copied and renamed to 'Sample 172.png'
# Image 'Sample 241.png' copied and renamed to 'Sample 173.png'
# Image 'Sample 253.png' copied and renamed to 'Sample 174.png'
# Image 'Sample 255.png' copied and renamed to 'Sample 175.png'
# Image 'Sample 277.png' copied and renamed to 'Sample 176.png'
# Image 'Sample 290.png' copied and renamed to 'Sample 177.png'
# Image 'Sample 301.png' copied and renamed to 'Sample 178.png'
# Image 'Sample 310.png' copied and renamed to 'Sample 179.png'
# Image 'Sample 323.png' copied and renamed to 'Sample 180.png'
# Image 'Sample 336.png' copied and renamed to 'Sample 181.png'
# Image 'Sample 34.png' copied and renamed to 'Sample 182.png'
# Image 'Sample 346.png' copied and renamed to 'Sample 183.png'
# Image 'Sample 351.png' copied and renamed to 'Sample 184.png'
# Image 'Sample 353.png' copied and renamed to 'Sample 185.png'
# Image 'Sample 36.png' copied and renamed to 'Sample 186.png'
# Image 'Sample 363.png' copied and renamed to 'Sample 187.png'
# Image 'Sample 378.png' copied and renamed to 'Sample 188.png'
# Image 'Sample 383.png' copied and renamed to 'Sample 189.png'
# Image 'Sample 392.png' copied and renamed to 'Sample 190.png'
# Image 'Sample 393.png' copied and renamed to 'Sample 191.png'
# Image 'Sample 395.png' copied and renamed to 'Sample 192.png'
# Image 'Sample 399.png' copied and renamed to 'Sample 193.png'
# Image 'Sample 403.png' copied and renamed to 'Sample 194.png'
# Image 'Sample 409.png' copied and renamed to 'Sample 195.png'
# Image 'Sample 427.png' copied and renamed to 'Sample 196.png'
# Image 'Sample 44.png' copied and renamed to 'Sample 197.png'
# Image 'Sample 440.png' copied and renamed to 'Sample 198.png'
# Image 'Sample 445.png' copied and renamed to 'Sample 199.png'
# Image 'Sample 446.png' copied and renamed to 'Sample 200.png'
# Image 'Sample 447.png' copied and renamed to 'Sample 201.png'
# Image 'Sample 449.png' copied and renamed to 'Sample 202.png'
# Image 'Sample 463.png' copied and renamed to 'Sample 203.png'
# Image 'Sample 479.png' copied and renamed to 'Sample 204.png'
# Image 'Sample 48.png' copied and renamed to 'Sample 205.png'
# Image 'Sample 490.png' copied and renamed to 'Sample 206.png'
# Image 'Sample 493.png' copied and renamed to 'Sample 207.png'
# Image 'Sample 494.png' copied and renamed to 'Sample 208.png'
# Image 'Sample 497.png' copied and renamed to 'Sample 209.png'
# Image 'Sample 502.png' copied and renamed to 'Sample 210.png'
# Image 'Sample 515.png' copied and renamed to 'Sample 211.png'
# Image 'Sample 519.png' copied and renamed to 'Sample 212.png'
# Image 'Sample 525.png' copied and renamed to 'Sample 213.png'
# Image 'Sample 526.png' copied and renamed to 'Sample 214.png'
# Image 'Sample 533.png' copied and renamed to 'Sample 215.png'
# Image 'Sample 538.png' copied and renamed to 'Sample 216.png'
# Image 'Sample 551.png' copied and renamed to 'Sample 217.png'
# Image 'Sample 552.png' copied and renamed to 'Sample 218.png'
# Image 'Sample 569.png' copied and renamed to 'Sample 219.png'
# Image 'Sample 570.png' copied and renamed to 'Sample 220.png'
# Image 'Sample 576.png' copied and renamed to 'Sample 221.png'
# Image 'Sample 58.png' copied and renamed to 'Sample 222.png'
# Image 'Sample 580.png' copied and renamed to 'Sample 223.png'
# Image 'Sample 583.png' copied and renamed to 'Sample 224.png'
# Image 'Sample 586.png' copied and renamed to 'Sample 225.png'
# Image 'Sample 598.png' copied and renamed to 'Sample 226.png'
# Image 'Sample 606.png' copied and renamed to 'Sample 227.png'
# Image 'Sample 612.png' copied and renamed to 'Sample 228.png'
# Image 'Sample 617.png' copied and renamed to 'Sample 229.png'
# Image 'Sample 62.png' copied and renamed to 'Sample 230.png'
# Image 'Sample 620.png' copied and renamed to 'Sample 231.png'
# Image 'Sample 623.png' copied and renamed to 'Sample 232.png'
# Image 'Sample 627.png' copied and renamed to 'Sample 233.png'
# Image 'Sample 639.png' copied and renamed to 'Sample 234.png'
# Image 'Sample 647.png' copied and renamed to 'Sample 235.png'
# Image 'Sample 656.png' copied and renamed to 'Sample 236.png'
# Image 'Sample 665.png' copied and renamed to 'Sample 237.png'
# Image 'Sample 668.png' copied and renamed to 'Sample 238.png'
# Image 'Sample 674.png' copied and renamed to 'Sample 239.png'
# Image 'Sample 687.png' copied and renamed to 'Sample 240.png'
# Image 'Sample 700.png' copied and renamed to 'Sample 241.png'
# Image 'Sample 707.png' copied and renamed to 'Sample 242.png'
# Image 'Sample 708.png' copied and renamed to 'Sample 243.png'
# Image 'Sample 709.png' copied and renamed to 'Sample 244.png'
# Image 'Sample 718.png' copied and renamed to 'Sample 245.png'
# Image 'Sample 720.png' copied and renamed to 'Sample 246.png'
# Image 'Sample 721.png' copied and renamed to 'Sample 247.png'
# Image 'Sample 726.png' copied and renamed to 'Sample 248.png'
# Image 'Sample 732.png' copied and renamed to 'Sample 249.png'
# Image 'Sample 733.png' copied and renamed to 'Sample 250.png'
# Image 'Sample 735.png' copied and renamed to 'Sample 251.png'
# Image 'Sample 738.png' copied and renamed to 'Sample 252.png'
# Image 'Sample 740.png' copied and renamed to 'Sample 253.png'
# Image 'Sample 746.png' copied and renamed to 'Sample 254.png'
# Image 'Sample 747.png' copied and renamed to 'Sample 255.png'
# Image 'Sample 753.png' copied and renamed to 'Sample 256.png'
# Image 'Sample 754.png' copied and renamed to 'Sample 257.png'
# Image 'Sample 756.png' copied and renamed to 'Sample 258.png'
# Image 'Sample 757.png' copied and renamed to 'Sample 259.png'
# Image 'Sample 758.png' copied and renamed to 'Sample 260.png'
# Image 'Sample 76.png' copied and renamed to 'Sample 261.png'
# Image 'Sample 761.png' copied and renamed to 'Sample 262.png'
# Image 'Sample 769.png' copied and renamed to 'Sample 263.png'
# Image 'Sample 782.png' copied and renamed to 'Sample 264.png'
# Image 'Sample 785.png' copied and renamed to 'Sample 265.png'
# Image 'Sample 79.png' copied and renamed to 'Sample 266.png'
# Image 'Sample 795.png' copied and renamed to 'Sample 267.png'
# Image 'Sample 797.png' copied and renamed to 'Sample 268.png'
# Image 'Sample 799.png' copied and renamed to 'Sample 269.png'
# Image 'Sample 80.png' copied and renamed to 'Sample 270.png'
# Image 'Sample 81.png' copied and renamed to 'Sample 271.png'
# Image 'Sample 826.png' copied and renamed to 'Sample 272.png'
# Image 'Sample 836.png' copied and renamed to 'Sample 273.png'
# Image 'Sample 84.png' copied and renamed to 'Sample 274.png'
# Image 'Sample 840.png' copied and renamed to 'Sample 275.png'
# Image 'Sample 844.png' copied and renamed to 'Sample 276.png'
# Image 'Sample 846.png' copied and renamed to 'Sample 277.png'
# Image 'Sample 848.png' copied and renamed to 'Sample 278.png'
# Image 'Sample 871.png' copied and renamed to 'Sample 279.png'
# Image 'Sample 874.png' copied and renamed to 'Sample 280.png'
# Image 'Sample 888.png' copied and renamed to 'Sample 281.png'
# Image 'Sample 891.png' copied and renamed to 'Sample 282.png'
# Image 'Sample 895.png' copied and renamed to 'Sample 283.png'
# Image 'Sample 906.png' copied and renamed to 'Sample 284.png'
# Image 'Sample 908.png' copied and renamed to 'Sample 285.png'
# Image 'Sample 917.png' copied and renamed to 'Sample 286.png'
# Image 'Sample 921.png' copied and renamed to 'Sample 287.png'
# Image 'Sample 927.png' copied and renamed to 'Sample 288.png'
# Image 'Sample 932.png' copied and renamed to 'Sample 289.png'
# Image 'Sample 941.png' copied and renamed to 'Sample 290.png'
# Image 'Sample 943.png' copied and renamed to 'Sample 291.png'
# Image 'Sample 950.png' copied and renamed to 'Sample 292.png'
# Image 'Sample 953.png' copied and renamed to 'Sample 293.png'
# Image 'Sample 954.png' copied and renamed to 'Sample 294.png'
# Image 'Sample 957.png' copied and renamed to 'Sample 295.png'
# Image 'Sample 959.png' copied and renamed to 'Sample 296.png'
# Image 'Sample 96.png' copied and renamed to 'Sample 297.png'
# Image 'Sample 990.png' copied and renamed to 'Sample 298.png'
# Image 'Sample 992.png' copied and renamed to 'Sample 299.png'
# Image 'Sample 999.png' copied and renamed to 'Sample 300.png'
# Image 'Sample 100.png' copied and renamed to 'Sample 301.png'
# Image 'Sample 101.png' copied and renamed to 'Sample 302.png'
# Image 'Sample 105.png' copied and renamed to 'Sample 303.png'
# Image 'Sample 108.png' copied and renamed to 'Sample 304.png'
# Image 'Sample 123.png' copied and renamed to 'Sample 305.png'
# Image 'Sample 13.png' copied and renamed to 'Sample 306.png'
# Image 'Sample 135.png' copied and renamed to 'Sample 307.png'
# Image 'Sample 144.png' copied and renamed to 'Sample 308.png'
# Image 'Sample 159.png' copied and renamed to 'Sample 309.png'
# Image 'Sample 16.png' copied and renamed to 'Sample 310.png'
# Image 'Sample 166.png' copied and renamed to 'Sample 311.png'
# Image 'Sample 168.png' copied and renamed to 'Sample 312.png'
# Image 'Sample 171.png' copied and renamed to 'Sample 313.png'
# Image 'Sample 184.png' copied and renamed to 'Sample 314.png'
# Image 'Sample 2.png' copied and renamed to 'Sample 315.png'
# Image 'Sample 20.png' copied and renamed to 'Sample 316.png'
# Image 'Sample 202.png' copied and renamed to 'Sample 317.png'
# Image 'Sample 204.png' copied and renamed to 'Sample 318.png'
# Image 'Sample 210.png' copied and renamed to 'Sample 319.png'
# Image 'Sample 213.png' copied and renamed to 'Sample 320.png'
# Image 'Sample 219.png' copied and renamed to 'Sample 321.png'
# Image 'Sample 22.png' copied and renamed to 'Sample 322.png'
# Image 'Sample 222.png' copied and renamed to 'Sample 323.png'
# Image 'Sample 230.png' copied and renamed to 'Sample 324.png'
# Image 'Sample 243.png' copied and renamed to 'Sample 325.png'
# Image 'Sample 250.png' copied and renamed to 'Sample 326.png'
# Image 'Sample 256.png' copied and renamed to 'Sample 327.png'
# Image 'Sample 267.png' copied and renamed to 'Sample 328.png'
# Image 'Sample 272.png' copied and renamed to 'Sample 329.png'
# Image 'Sample 28.png' copied and renamed to 'Sample 330.png'
# Image 'Sample 284.png' copied and renamed to 'Sample 331.png'
# Image 'Sample 300.png' copied and renamed to 'Sample 332.png'
# Image 'Sample 309.png' copied and renamed to 'Sample 333.png'
# Image 'Sample 311.png' copied and renamed to 'Sample 334.png'
# Image 'Sample 317.png' copied and renamed to 'Sample 335.png'
# Image 'Sample 319.png' copied and renamed to 'Sample 336.png'
# Image 'Sample 324.png' copied and renamed to 'Sample 337.png'
# Image 'Sample 341.png' copied and renamed to 'Sample 338.png'
# Image 'Sample 348.png' copied and renamed to 'Sample 339.png'
# Image 'Sample 36.png' copied and renamed to 'Sample 340.png'
# Image 'Sample 362.png' copied and renamed to 'Sample 341.png'
# Image 'Sample 366.png' copied and renamed to 'Sample 342.png'
# Image 'Sample 375.png' copied and renamed to 'Sample 343.png'
# Image 'Sample 385.png' copied and renamed to 'Sample 344.png'
# Image 'Sample 397.png' copied and renamed to 'Sample 345.png'
# Image 'Sample 399.png' copied and renamed to 'Sample 346.png'
# Image 'Sample 406.png' copied and renamed to 'Sample 347.png'
# Image 'Sample 411.png' copied and renamed to 'Sample 348.png'
# Image 'Sample 412.png' copied and renamed to 'Sample 349.png'
# Image 'Sample 415.png' copied and renamed to 'Sample 350.png'
# Image 'Sample 416.png' copied and renamed to 'Sample 351.png'
# Image 'Sample 427.png' copied and renamed to 'Sample 352.png'
# Image 'Sample 431.png' copied and renamed to 'Sample 353.png'
# Image 'Sample 441.png' copied and renamed to 'Sample 354.png'
# Image 'Sample 442.png' copied and renamed to 'Sample 355.png'
# Image 'Sample 448.png' copied and renamed to 'Sample 356.png'
# Image 'Sample 452.png' copied and renamed to 'Sample 357.png'
# Image 'Sample 455.png' copied and renamed to 'Sample 358.png'
# Image 'Sample 458.png' copied and renamed to 'Sample 359.png'
# Image 'Sample 463.png' copied and renamed to 'Sample 360.png'
# Image 'Sample 469.png' copied and renamed to 'Sample 361.png'
# Image 'Sample 472.png' copied and renamed to 'Sample 362.png'
# Image 'Sample 48.png' copied and renamed to 'Sample 363.png'
# Image 'Sample 482.png' copied and renamed to 'Sample 364.png'
# Image 'Sample 483.png' copied and renamed to 'Sample 365.png'
# Image 'Sample 489.png' copied and renamed to 'Sample 366.png'
# Image 'Sample 50.png' copied and renamed to 'Sample 367.png'
# Image 'Sample 504.png' copied and renamed to 'Sample 368.png'
# Image 'Sample 515.png' copied and renamed to 'Sample 369.png'
# Image 'Sample 526.png' copied and renamed to 'Sample 370.png'
# Image 'Sample 527.png' copied and renamed to 'Sample 371.png'
# Image 'Sample 533.png' copied and renamed to 'Sample 372.png'
# Image 'Sample 535.png' copied and renamed to 'Sample 373.png'
# Image 'Sample 541.png' copied and renamed to 'Sample 374.png'
# Image 'Sample 546.png' copied and renamed to 'Sample 375.png'
# Image 'Sample 547.png' copied and renamed to 'Sample 376.png'
# Image 'Sample 557.png' copied and renamed to 'Sample 377.png'
# Image 'Sample 584.png' copied and renamed to 'Sample 378.png'
# Image 'Sample 592.png' copied and renamed to 'Sample 379.png'
# Image 'Sample 60.png' copied and renamed to 'Sample 380.png'
# Image 'Sample 609.png' copied and renamed to 'Sample 381.png'
# Image 'Sample 629.png' copied and renamed to 'Sample 382.png'
# Image 'Sample 633.png' copied and renamed to 'Sample 383.png'
# Image 'Sample 634.png' copied and renamed to 'Sample 384.png'
# Image 'Sample 637.png' copied and renamed to 'Sample 385.png'
# Image 'Sample 644.png' copied and renamed to 'Sample 386.png'
# Image 'Sample 648.png' copied and renamed to 'Sample 387.png'
# Image 'Sample 655.png' copied and renamed to 'Sample 388.png'
# Image 'Sample 660.png' copied and renamed to 'Sample 389.png'
# Image 'Sample 662.png' copied and renamed to 'Sample 390.png'
# Image 'Sample 673.png' copied and renamed to 'Sample 391.png'
# Image 'Sample 680.png' copied and renamed to 'Sample 392.png'
# Image 'Sample 681.png' copied and renamed to 'Sample 393.png'
# Image 'Sample 695.png' copied and renamed to 'Sample 394.png'
# Image 'Sample 698.png' copied and renamed to 'Sample 395.png'
# Image 'Sample 71.png' copied and renamed to 'Sample 396.png'
# Image 'Sample 715.png' copied and renamed to 'Sample 397.png'
# Image 'Sample 716.png' copied and renamed to 'Sample 398.png'
# Image 'Sample 717.png' copied and renamed to 'Sample 399.png'
# Image 'Sample 722.png' copied and renamed to 'Sample 400.png'
# Image 'Sample 728.png' copied and renamed to 'Sample 401.png'
# Image 'Sample 735.png' copied and renamed to 'Sample 402.png'
# Image 'Sample 741.png' copied and renamed to 'Sample 403.png'
# Image 'Sample 743.png' copied and renamed to 'Sample 404.png'
# Image 'Sample 764.png' copied and renamed to 'Sample 405.png'
# Image 'Sample 77.png' copied and renamed to 'Sample 406.png'
# Image 'Sample 771.png' copied and renamed to 'Sample 407.png'
# Image 'Sample 779.png' copied and renamed to 'Sample 408.png'
# Image 'Sample 787.png' copied and renamed to 'Sample 409.png'
# Image 'Sample 79.png' copied and renamed to 'Sample 410.png'
# Image 'Sample 808.png' copied and renamed to 'Sample 411.png'
# Image 'Sample 815.png' copied and renamed to 'Sample 412.png'
# Image 'Sample 817.png' copied and renamed to 'Sample 413.png'
# Image 'Sample 820.png' copied and renamed to 'Sample 414.png'
# Image 'Sample 825.png' copied and renamed to 'Sample 415.png'
# Image 'Sample 83.png' copied and renamed to 'Sample 416.png'
# Image 'Sample 832.png' copied and renamed to 'Sample 417.png'
# Image 'Sample 851.png' copied and renamed to 'Sample 418.png'
# Image 'Sample 858.png' copied and renamed to 'Sample 419.png'
# Image 'Sample 863.png' copied and renamed to 'Sample 420.png'
# Image 'Sample 866.png' copied and renamed to 'Sample 421.png'
# Image 'Sample 868.png' copied and renamed to 'Sample 422.png'
# Image 'Sample 87.png' copied and renamed to 'Sample 423.png'
# Image 'Sample 878.png' copied and renamed to 'Sample 424.png'
# Image 'Sample 881.png' copied and renamed to 'Sample 425.png'
# Image 'Sample 890.png' copied and renamed to 'Sample 426.png'
# Image 'Sample 893.png' copied and renamed to 'Sample 427.png'
# Image 'Sample 903.png' copied and renamed to 'Sample 428.png'
# Image 'Sample 910.png' copied and renamed to 'Sample 429.png'
# Image 'Sample 912.png' copied and renamed to 'Sample 430.png'
# Image 'Sample 914.png' copied and renamed to 'Sample 431.png'
# Image 'Sample 916.png' copied and renamed to 'Sample 432.png'
# Image 'Sample 918.png' copied and renamed to 'Sample 433.png'
# Image 'Sample 92.png' copied and renamed to 'Sample 434.png'
# Image 'Sample 930.png' copied and renamed to 'Sample 435.png'
# Image 'Sample 934.png' copied and renamed to 'Sample 436.png'
# Image 'Sample 936.png' copied and renamed to 'Sample 437.png'
# Image 'Sample 94.png' copied and renamed to 'Sample 438.png'
# Image 'Sample 940.png' copied and renamed to 'Sample 439.png'
# Image 'Sample 944.png' copied and renamed to 'Sample 440.png'
# Image 'Sample 946.png' copied and renamed to 'Sample 441.png'
# Image 'Sample 954.png' copied and renamed to 'Sample 442.png'
# Image 'Sample 958.png' copied and renamed to 'Sample 443.png'
# Image 'Sample 964.png' copied and renamed to 'Sample 444.png'
# Image 'Sample 977.png' copied and renamed to 'Sample 445.png'
# Image 'Sample 978.png' copied and renamed to 'Sample 446.png'
# Image 'Sample 979.png' copied and renamed to 'Sample 447.png'
# Image 'Sample 983.png' copied and renamed to 'Sample 448.png'
# Image 'Sample 989.png' copied and renamed to 'Sample 449.png'
# Image 'Sample 994.png' copied and renamed to 'Sample 450.png'

# %% [markdown]
# #### Test

# %%
import os
import shutil

def copy_and_rename_images(source_folders, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Initialize a counter for renaming
    counter = 1

    # Loop through each source folder
    for folder in source_folders:
        # Check if the source folder exists
        if not os.path.exists(folder):
            print(f"Source folder '{folder}' does not exist.")
            continue

        # Get list of image files in the source folder
        image_files = [file for file in os.listdir(folder) if file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]

        # Copy and rename each image
        for image in image_files:
            source_path = os.path.join(folder, image)
            destination_path = os.path.join(destination_folder, f"Sample {counter}.png")  # Renaming as Sample{counter}.jpg
            shutil.copyfile(source_path, destination_path)
            print(f"Image '{image}' copied and renamed to 'Sample {counter}.png'")
            counter += 1

# Source folders
source_folders = ['./test/resonator', './test/centermass', './test/diaphragm']
destination_folder = './test/defected'

# Copy and rename images
copy_and_rename_images(source_folders, destination_folder)
# Out:
# Image 'Sample 150.png' copied and renamed to 'Sample 1.png'
# Image 'Sample 153.png' copied and renamed to 'Sample 2.png'
# Image 'Sample 156.png' copied and renamed to 'Sample 3.png'
# Image 'Sample 158.png' copied and renamed to 'Sample 4.png'
# Image 'Sample 184.png' copied and renamed to 'Sample 5.png'
# Image 'Sample 232.png' copied and renamed to 'Sample 6.png'
# Image 'Sample 248.png' copied and renamed to 'Sample 7.png'
# Image 'Sample 259.png' copied and renamed to 'Sample 8.png'
# Image 'Sample 316.png' copied and renamed to 'Sample 9.png'
# Image 'Sample 319.png' copied and renamed to 'Sample 10.png'
# Image 'Sample 373.png' copied and renamed to 'Sample 11.png'
# Image 'Sample 402.png' copied and renamed to 'Sample 12.png'
# Image 'Sample 425.png' copied and renamed to 'Sample 13.png'
# Image 'Sample 447.png' copied and renamed to 'Sample 14.png'
# Image 'Sample 458.png' copied and renamed to 'Sample 15.png'
# Image 'Sample 476.png' copied and renamed to 'Sample 16.png'
# Image 'Sample 488.png' copied and renamed to 'Sample 17.png'
# Image 'Sample 499.png' copied and renamed to 'Sample 18.png'
# Image 'Sample 50.png' copied and renamed to 'Sample 19.png'
# Image 'Sample 533.png' copied and renamed to 'Sample 20.png'
# Image 'Sample 573.png' copied and renamed to 'Sample 21.png'
# Image 'Sample 618.png' copied and renamed to 'Sample 22.png'
# Image 'Sample 628.png' copied and renamed to 'Sample 23.png'
# Image 'Sample 674.png' copied and renamed to 'Sample 24.png'
# Image 'Sample 736.png' copied and renamed to 'Sample 25.png'
# Image 'Sample 753.png' copied and renamed to 'Sample 26.png'
# Image 'Sample 773.png' copied and renamed to 'Sample 27.png'
# Image 'Sample 784.png' copied and renamed to 'Sample 28.png'
# Image 'Sample 903.png' copied and renamed to 'Sample 29.png'
# Image 'Sample 991.png' copied and renamed to 'Sample 30.png'
# Image 'Sample 109.png' copied and renamed to 'Sample 31.png'
# Image 'Sample 112.png' copied and renamed to 'Sample 32.png'
# Image 'Sample 130.png' copied and renamed to 'Sample 33.png'
# Image 'Sample 196.png' copied and renamed to 'Sample 34.png'
# Image 'Sample 204.png' copied and renamed to 'Sample 35.png'
# Image 'Sample 227.png' copied and renamed to 'Sample 36.png'
# Image 'Sample 259.png' copied and renamed to 'Sample 37.png'
# Image 'Sample 266.png' copied and renamed to 'Sample 38.png'
# Image 'Sample 279.png' copied and renamed to 'Sample 39.png'
# Image 'Sample 3.png' copied and renamed to 'Sample 40.png'
# Image 'Sample 317.png' copied and renamed to 'Sample 41.png'
# Image 'Sample 319.png' copied and renamed to 'Sample 42.png'
# Image 'Sample 330.png' copied and renamed to 'Sample 43.png'
# Image 'Sample 355.png' copied and renamed to 'Sample 44.png'
# Image 'Sample 361.png' copied and renamed to 'Sample 45.png'
# Image 'Sample 366.png' copied and renamed to 'Sample 46.png'
# Image 'Sample 401.png' copied and renamed to 'Sample 47.png'
# Image 'Sample 448.png' copied and renamed to 'Sample 48.png'
# Image 'Sample 461.png' copied and renamed to 'Sample 49.png'
# Image 'Sample 555.png' copied and renamed to 'Sample 50.png'
# Image 'Sample 603.png' copied and renamed to 'Sample 51.png'
# Image 'Sample 655.png' copied and renamed to 'Sample 52.png'
# Image 'Sample 666.png' copied and renamed to 'Sample 53.png'
# Image 'Sample 811.png' copied and renamed to 'Sample 54.png'
# Image 'Sample 813.png' copied and renamed to 'Sample 55.png'
# Image 'Sample 816.png' copied and renamed to 'Sample 56.png'
# Image 'Sample 910.png' copied and renamed to 'Sample 57.png'
# Image 'Sample 923.png' copied and renamed to 'Sample 58.png'
# Image 'Sample 964.png' copied and renamed to 'Sample 59.png'
# Image 'Sample 988.png' copied and renamed to 'Sample 60.png'
# Image 'Sample 207.png' copied and renamed to 'Sample 61.png'
# Image 'Sample 233.png' copied and renamed to 'Sample 62.png'
# Image 'Sample 257.png' copied and renamed to 'Sample 63.png'
# Image 'Sample 318.png' copied and renamed to 'Sample 64.png'
# Image 'Sample 329.png' copied and renamed to 'Sample 65.png'
# Image 'Sample 349.png' copied and renamed to 'Sample 66.png'
# Image 'Sample 372.png' copied and renamed to 'Sample 67.png'
# Image 'Sample 380.png' copied and renamed to 'Sample 68.png'
# Image 'Sample 381.png' copied and renamed to 'Sample 69.png'
# Image 'Sample 384.png' copied and renamed to 'Sample 70.png'
# Image 'Sample 395.png' copied and renamed to 'Sample 71.png'
# Image 'Sample 402.png' copied and renamed to 'Sample 72.png'
# Image 'Sample 413.png' copied and renamed to 'Sample 73.png'
# Image 'Sample 46.png' copied and renamed to 'Sample 74.png'
# Image 'Sample 498.png' copied and renamed to 'Sample 75.png'
# Image 'Sample 544.png' copied and renamed to 'Sample 76.png'
# Image 'Sample 586.png' copied and renamed to 'Sample 77.png'
# Image 'Sample 597.png' copied and renamed to 'Sample 78.png'
# Image 'Sample 607.png' copied and renamed to 'Sample 79.png'
# Image 'Sample 63.png' copied and renamed to 'Sample 80.png'
# Image 'Sample 640.png' copied and renamed to 'Sample 81.png'
# Image 'Sample 718.png' copied and renamed to 'Sample 82.png'
# Image 'Sample 731.png' copied and renamed to 'Sample 83.png'
# Image 'Sample 789.png' copied and renamed to 'Sample 84.png'
# Image 'Sample 84.png' copied and renamed to 'Sample 85.png'
# Image 'Sample 865.png' copied and renamed to 'Sample 86.png'
# Image 'Sample 907.png' copied and renamed to 'Sample 87.png'
# Image 'Sample 931.png' copied and renamed to 'Sample 88.png'
# Image 'Sample 932.png' copied and renamed to 'Sample 89.png'
# Image 'Sample 955.png' copied and renamed to 'Sample 90.png'
