# %% [markdown]
# #### import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# %% [markdown]
# #### Load the dataset

# %%
good = pd.read_csv('..\good horn.csv')
resonator = pd.read_csv('../resonator.csv')
centermass = pd.read_csv('..\centermass.csv')
diaphragm = pd.read_csv('../diaphragm.csv')

max_cols = min(len(good), min(len(resonator), min(len(centermass), len(diaphragm))))

# %%
good = good[:max_cols]
resonator = resonator[:max_cols]
centermass = centermass[:max_cols]
diaphragm = diaphragm[:max_cols]

# %%
good = good.set_index(good.iloc[:, 0])
good = good.drop('Time(s)', axis = 1)

resonator = resonator.set_index(resonator.iloc[:, 0])
resonator = resonator.drop('Time(s)', axis = 1)

centermass = centermass.set_index(centermass.iloc[:, 0])
centermass = centermass.drop('Time(s)', axis = 1)

diaphragm = diaphragm.set_index(diaphragm.iloc[:, 0])
diaphragm = diaphragm.drop('Time(s)', axis = 1)

# %%
good = good.transpose()
resonator = resonator.transpose()
centermass = centermass.transpose()
diaphragm = diaphragm.transpose()

# %%
good.head()
# Out:
# Time(s)   0.00   0.02    0.04    0.06    0.08    0.10    0.12    0.14   \
# 1        0.3531  0.017 -0.3108  0.0597  0.1928 -0.0188 -0.0078 -0.0344
# 2        0.2301 -0.106 -0.4338 -0.0633  0.0698 -0.1418 -0.1308 -0.1574
# 3        0.1301 -0.206 -0.5338 -0.1633 -0.0302 -0.2418 -0.2308 -0.2574
# 4        0.0301 -0.306 -0.6338 -0.2633 -0.1302 -0.3418 -0.3308 -0.3574
# 5        0.1231 -0.213 -0.5408 -0.1703 -0.0372 -0.2488 -0.2378 -0.2644
#
# Time(s)   0.16    0.18   ...   21.84  21.86   21.88   21.90   21.92   21.94  \
# 1       -0.0243 -0.3884  ... -0.2273  0.478  0.0266 -0.3062 -0.0051  0.1983
# 2       -0.1473 -0.5114  ... -0.3503  0.355 -0.0964 -0.4292 -0.1281  0.0753
# 3       -0.2473 -0.6114  ... -0.4503  0.255 -0.1964 -0.5292 -0.2281 -0.0247
# 4       -0.3473 -0.7114  ... -0.5503  0.155 -0.2964 -0.6292 -0.3281 -0.1247
# 5       -0.2543 -0.6184  ... -0.4573  0.248 -0.2034 -0.5362 -0.2351 -0.0317
#
# Time(s)   21.96   21.98   22.00   22.02
# 1       -0.0014 -0.0064 -0.0441  0.0565
# 2       -0.1244 -0.1294 -0.1671 -0.0665
# 3       -0.2244 -0.2294 -0.2671 -0.1665
# 4       -0.3244 -0.3294 -0.3671 -0.2665
# 5       -0.2314 -0.2364 -0.2741 -0.1735
#
# [5 rows x 1120 columns]

# %%
good['target'] = 0
resonator['target'] = 1
centermass['target'] = 2
diaphragm['target'] = 3

# %% [markdown]
# #### Compile all together

# %%
compiled = pd.concat([good, resonator, centermass, diaphragm], axis = 0, ignore_index=True)

# %%
compiled.head()
compiled.to_csv('compiled.csv')

# %% [markdown]
# ### Oversample SMOTE

# %%
X = compiled.drop('target', axis = 1)
y = compiled.target

# %% [markdown]
# #### Apply SMOTE

# %%
smote = SMOTE(sampling_strategy={0: 1000, 1:1000, 2:1000, 3:1000})

# %%
x_resamp, y_resamp = smote.fit_resample(X, y)

# %%
x_resamp = pd.DataFrame(x_resamp)
y_resamp = pd.DataFrame(y_resamp)
oversampled_data = pd.concat([x_resamp, y_resamp], axis = 1)

# %%
oversampled_data.to_csv('oversampled.csv')

# %% [markdown]
# ### Check

# %%
oversampled_data.target.value_counts()
# Out:
# target
# 0    1000
# 1    1000
# 2    1000
# 3    1000
# Name: count, dtype: int64

# %%
compiled.describe()
# Out:
# Time(s)        0.0       0.02       0.04       0.06       0.08        0.1  \
# count    49.000000  49.000000  49.000000  49.000000  49.000000  49.000000
# mean      0.034553  -0.103669  -0.161178  -0.035133  -0.044661  -0.050549
# std       0.187082   0.184812   0.258814   0.196912   0.251454   0.242751
# min      -0.751400  -0.797900  -0.835500  -0.759600  -0.987400  -0.793700
# 25%      -0.057900  -0.197900  -0.362200  -0.137300  -0.174100  -0.193000
# 50%       0.061900  -0.102700  -0.090100  -0.031900  -0.037200  -0.056000
# 75%       0.137500   0.012100   0.009900   0.053700   0.095800   0.025800
# max       0.353100   0.235700   0.259900   0.353000   0.421800   0.453300
#
# Time(s)       0.12       0.14       0.16       0.18  ...      21.86  \
# count    49.000000  49.000000  49.000000  49.000000  ...  49.000000
# mean     -0.062520  -0.157763  -0.046104  -0.201967  ...   0.017486
# std       0.204898   0.241421   0.188188   0.297263  ...   0.273878
# min      -0.840200  -0.930300  -0.744900  -0.853800  ...  -0.687800
# 25%      -0.180200  -0.270300  -0.147300  -0.455400  ...  -0.183000
# 50%      -0.045000  -0.157400  -0.024300  -0.121100  ...   0.114000
# 75%       0.015300  -0.065300   0.073700  -0.035200  ...   0.180000
# max       0.347700   0.334700   0.282300   0.330600  ...   0.478000
#
# Time(s)      21.88       21.9      21.92      21.94      21.96      21.98  \
# count    49.000000  49.000000  49.000000  49.000000  49.000000  49.000000
# mean      0.041041  -0.221400  -0.067533  -0.155561  -0.116412   0.010147
# std       0.267854   0.250915   0.183456   0.347781   0.209701   0.209909
# min      -0.832000  -0.904400  -0.702500  -0.943300  -0.804900  -0.703100
# 25%      -0.136800  -0.403200  -0.170100  -0.507300  -0.224400  -0.103400
# 50%      -0.013400  -0.193700  -0.046100  -0.047900  -0.124400   0.033900
# 75%       0.206200  -0.091100   0.092700   0.075300   0.005100   0.119900
# max       0.544200   0.256300   0.238000   0.334800   0.283700   0.401200
#
# Time(s)       22.0      22.02     target
# count    49.000000  49.000000  49.000000
# mean      0.146692  -0.057484   1.469388
# std       0.282736   0.248352   1.138384
# min      -0.557100  -0.883200   0.000000
# 25%      -0.069100  -0.188000   0.000000
# 50%       0.222900  -0.075700   1.000000
# 75%       0.377800   0.031500   2.000000
# max       0.555700   0.459500   3.000000
#
# [8 rows x 1121 columns]

# %%
oversampled_data.describe()
# Out:
#                0.0         0.02         0.04         0.06         0.08  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.043717    -0.090383    -0.142259    -0.021308    -0.033808
# std       0.150131     0.157551     0.240744     0.170771     0.222660
# min      -0.751400    -0.797900    -0.835500    -0.759600    -0.987400
# 25%      -0.038029    -0.185587    -0.345328    -0.131438    -0.177000
# 50%       0.064603    -0.091837    -0.059231    -0.019617    -0.046568
# 75%       0.133733     0.011286     0.009301     0.054260     0.100473
# max       0.353100     0.235700     0.259900     0.353000     0.421800
#
#                0.1         0.12         0.14         0.16         0.18  ...  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000  ...
# mean     -0.035409    -0.047859    -0.144533    -0.030758    -0.182283  ...
# std       0.221921     0.178394     0.218721     0.162524     0.281707  ...
# min      -0.793700    -0.840200    -0.930300    -0.744900    -0.853800  ...
# 25%      -0.185728    -0.166832    -0.272274    -0.140483    -0.433505  ...
# 50%      -0.059718    -0.039530    -0.158818    -0.012281    -0.110584  ...
# 75%       0.033695     0.027848    -0.065247     0.073305    -0.034923  ...
# max       0.453300     0.347700     0.334700     0.282300     0.330600  ...
#
#              21.86        21.88         21.9        21.92        21.94  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.023692     0.057142    -0.203833    -0.053033    -0.147133
# std       0.247189     0.246073     0.232499     0.159366     0.330006
# min      -0.687800    -0.832000    -0.904400    -0.702500    -0.943300
# 25%      -0.176242    -0.115273    -0.395695    -0.168460    -0.514544
# 50%       0.115036    -0.017836    -0.160441    -0.047445    -0.046211
# 75%       0.184212     0.213326    -0.087383     0.103289     0.070904
# max       0.478000     0.544200     0.256300     0.238000     0.334800
#
#              21.96        21.98         22.0        22.02       target
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean     -0.103008     0.026292     0.166467    -0.044058     1.500000
# std       0.186346     0.186768     0.265163     0.224895     1.118174
# min      -0.804900    -0.703100    -0.557100    -0.883200     0.000000
# 25%      -0.219077    -0.106145    -0.074706    -0.174064     0.750000
# 50%      -0.116221     0.062341     0.244621    -0.076801     1.500000
# 75%       0.007031     0.124263     0.385753     0.038186     2.250000
# max       0.283700     0.401200     0.555700     0.459500     3.000000
#
# [8 rows x 1121 columns]
